# %% [markdown]
# # <h1 style='text-align:center'>📘 Mathematics for Data Science & Generative AI</h1>
#
# ---
# ---
#
# ## 1️⃣ Algebra Basics
#
# ### 🔹 Brief Intro
# Algebra is the language of variables and equations. It helps represent relationships between quantities—critical for building models and algorithms.
#
# ### 🔹 Key Points
# - Variables & constants
# - Linear & nonlinear equations
# - Inequalities
# - Solving equations
# - Expressions & simplification
#
# ### 🔹 Important Formulas
# - Linear equation:
#   $$
#   ax + b = 0
#   $$
# - Quadratic equation:
#   $$
#   ax^2 + bx + c = 0
#   $$
# - Exponent rule:
#  $$
#   a^m \cdot a^n = a^{m+n}
#  $$
#
# ### 🔹 Real-World Example (Data Science)
# **Salary Prediction Model**
# $$
# Salary = a \times Experience + b
# $$
# Here, algebra defines how experience impacts salary.
#
# ### 🔹 GenAI Connection
# - Loss functions use algebraic expressions
# - Model parameters (weights & biases) are algebraic variables
# - Prompt scoring & optimization relies on algebra
#
# 📌 **Career Use:** ML Engineer, Data Analyst, AI Researcher
#
# ---
#
# ## 2️⃣ Functions
#
# ### 🔹 Brief Intro
# A function maps inputs to outputs. Models in ML and AI are essentially complex functions.
#
# ### 🔹 Key Points
# - Domain & range
# - Linear, polynomial, exponential functions
# - Composite functions
# - Activation functions
#
# ### 🔹 Important Formulas
# - General function:
#  $$
#   f(x) = y
#  $$
# - Linear function:
#   $$
#   f(x) = mx + c
#   $$
# - Sigmoid (used in ML):
#   $$
#   \sigma(x) = \frac{1}{1 + e^{-x}}
#   $$
#
#
# ### 🔹 Real-World Example (Data Science)
# **House Price Prediction**
# \[
# Price = f(Size, Location, Rooms)
# \]
#
# ### 🔹 GenAI Connection
# - Neural networks are **nested functions**
# - Transformers use nonlinear activation functions
# - LLMs map text → probability distributions
#
# 📌 **Career Use:** ML Engineer, Deep Learning Engineer
#
# ---
#
# ##  3️⃣ Statistics (Mean, Median, Mode, Variance)
#
# ### 🔹 Brief Intro
# Statistics summarizes and analyzes data, helping derive insights and validate models.
#
# ---
#
# ### 📊 Mean
# $$
# \mu = \frac{1}{n}\sum x
# $$
# **Use:** Average user engagement
#
# ---
#
# ### 📊 Median
# Middle value after sorting
# **Use:** Income analysis (robust to outliers)
#
# ---
#
# ### 📊 Mode
# Most frequent value
# **Use:** Most common search query
#
# ---
#
# ### 📊 Variance
# $$
# \sigma^2 = \frac{1}{n}\sum (x - \mu)^2
# $$
#
# ### 📊 Standard Deviation
# $$
# \sigma = \sqrt{\sigma^2}
# $$
#
# ### 🔹 Real-World Example (Data Science)
# **Customer Purchase Analysis**
# - Mean: Average spend
# - Variance: Spending stability
#
# ### 🔹 GenAI Connection
# - Model evaluation metrics
# - Dataset distribution analysis
# - Detecting bias & hallucinations
#
# 📌 **Career Use:** Data Analyst, AI Evaluator
#
# ---
#
# ## 4️⃣ Vectors & Matrices (Basics)
#
# ### 🔹 Brief Intro
# Vectors & matrices power machine learning, neural networks, and embeddings.
#
# ---
#
# ### 🔹 Vectors
#
# **Key Points**
# - Direction & magnitude
# - Dot product
# - Feature representation
#
# **Formula**
# $$
# \vec{v} = [v_1, v_2, ..., v_n]
# $$
#
# **Dot Product**
# $$
# \vec{a} \cdot \vec{b} = \sum a_i b_i
# $$
#
# ---
#
# ### 🔹 Matrices
#
# **Key Points**
# - 2D data representation
# - Matrix multiplication
# - Transformations
#
# **Formula**
# $$
# C = A \times B
# $$
#
# ---
#
# ### 🔹 Real-World Example (Data Science)
# **Recommendation Systems**
# - Users = vectors
# - Products = vectors
# - Similarity via dot product
#
# ### 🔹 GenAI Connection
# - Word embeddings (Word2Vec, BERT)
# - Attention mechanisms
# - Transformer architecture
#
# 📌 **Career Use:** ML Engineer, GenAI Engineer
#
# ---
#
# # 🚀 How This Math Shapes Your Career
#
# | Role | Math Used |
# |-----|----------|
# | Data Analyst | Algebra, Statistics |
# | Data Scientist | Probability, Functions |
# | ML Engineer | Linear Algebra, Functions |
# | GenAI Engineer | Vectors, Probability, Statistics |
# | AI Researcher | All of the above |
#
# ---
#
# # <center> *End of Topic </center>
